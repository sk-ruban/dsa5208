# %% [markdown]
# ### <u>DSA5208 Project 2: Using MLlib to predict air pressure</u>
#
# Done by: S K Ruban A0253837W ,Owen Li Dong Lin A0231088H
#
# This notebook is organised in the following structure:<br>
#     **1. Import libraries**<br>
#     **2. Initialize Spark session**<br>
#     **3. Data Cleaning & Preprocessing**<br>
#         &emsp;3.1 Load and clean data from all extracted .csv files<br>
#         &emsp;3.2 Prepare data by applying MinMax scaling<br>
#         &emsp;3.3 Split data into train and test sets<br>
#         &emsp;3.4 Assemble feature vector for model training<br>
#     **4. Model Training**<br>
#         &emsp;4.1 Cache training and test data for faster processing<br>
#         &emsp;4.2 Define regression models<br>
#         &emsp;4.3 Define model parameter grids for hyperparameter tuning<br>
#         &emsp;4.4 Define RegressionEvaluator & CrossValidators for each model<br>
#         &emsp;4.5 Create pipelines and fit each model<br>
#         &emsp;4.6 Make predictions on the train and test sets<br>
#     **5. Model Evaluation & Optimization**<br>
#         &emsp;5.1 Calculate RMSE of model predictions on train and test sets<br>
#         &emsp;5.2 Identify the optimized hyperparameters for each model<br>

# %% [markdown]
# # 1. Import libraries

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, split, substring, when
from pyspark.ml.feature import VectorAssembler, MinMaxScaler
from pyspark.ml.regression import LinearRegression, DecisionTreeRegressor, RandomForestRegressor, GBTRegressor
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml import Pipeline
import sys
import os
from time import time

# %% [markdown]
# # 2. Initialize Spark session

# %%
spark = SparkSession.builder \
    .appName("Weather Pressure Prediction") \
    .config("spark.ui.showConsoleProgress", "false") \
    .getOrCreate()
spark.sparkContext.setLogLevel("ERROR")
# Out:
# 24/11/16 13:26:09 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %% [markdown]
# # 3. Data Cleaning & Preprocessing

# %% [markdown]
# ### 3.1 Load and clean data from all extracted .csv files

# %%
df = spark.read.csv("gs://dsa5208-proj2/extracted/*.csv", header=True, inferSchema=True)

selected_columns = ["LATITUDE", "LONGITUDE", "ELEVATION", "WND", "CIG", "VIS", "TMP", "DEW", "SLP"]

df = df.select(selected_columns).cache()

df_parsed = df.select(
        # Latitude: +99999 is missing
        when(col("LATITUDE").contains("+99999"), None)
        .otherwise(col("LATITUDE").cast("double"))
        .alias("latitude"),

        # Longitude: +999999 is missing
        when(col("LONGITUDE").contains("+999999"), None)
        .otherwise(col("LONGITUDE").cast("double"))
        .alias("longitude"),

        # Elevation: +9999 is missing
        when(col("ELEVATION").contains("+9999"), None)
        .otherwise(col("ELEVATION").cast("double"))
        .alias("elevation"),

        # Wind direction: 999 is missing
        when(split(col("WND"), ",").getItem(0) == "999", None)
        .otherwise(split(col("WND"), ",").getItem(0).cast("double"))
        .alias("wind_direction"),

        # Wind speed: 9999 is missing in fourth position
        when(split(col("WND"), ",").getItem(3) == "9999", None)
        .otherwise(split(col("WND"), ",").getItem(3).cast("double"))
        .alias("wind_speed"),

        # Ceiling height: 99999 is missing
        when(split(col("CIG"), ",").getItem(0) == "99999", None)
        .otherwise(split(col("CIG"), ",").getItem(0).cast("double"))
        .alias("ceiling_height"),

        # Visibility: 999999 is missing
        when(split(col("VIS"), ",").getItem(0) == "999999", None)
        .otherwise(split(col("VIS"), ",").getItem(0).cast("double"))
        .alias("visibility"),

        # Air temperature: +9999 is missing
        when(col("TMP").contains("+9999"), None)
        .otherwise(split(col("TMP"), ",").getItem(0).cast("double"))
        .alias("air_temp"),

        # Dew point: +9999 is missing
        when(col("DEW").contains("+9999"), None)
        .otherwise(split(col("DEW"), ",").getItem(0).cast("double"))
        .alias("dew_point"),

        # Sea level pressure: 99999 is missing
        when(split(col("SLP"), ",").getItem(0) == "99999", None)
        .otherwise(split(col("SLP"), ",").getItem(0).cast("double"))
        .alias("sea_level_pressure")
    )

df.unpersist()
print("\nSample of parsed data:")
df_parsed.show(20)

print("\nNull counts after parsing:")
for column in df_parsed.columns:
    null_count = df_parsed.filter(col(column).isNull()).count()
    total = df_parsed.count()
    print(f"{column}: {null_count} nulls out of {total} ({(null_count/total)*100:.2f}%)")

print("\nRemoving rows with null values...")
df_no_nulls = df_parsed.dropna().cache()

rows_after_null_removal = df_no_nulls.count()
print(f"Rows remaining after null removal: {rows_after_null_removal}")

print("\nApplying valid range filters...")
df_filtered = df_no_nulls.filter(
    (col("latitude").between(-90000, 90000)) &
    (col("longitude").between(-179999, 180000)) &
    (col("elevation").between(-400, 8850)) &
    (col("wind_direction").between(1, 360)) &
    (col("wind_speed").between(0, 900)) &
    (co4l("ceiling_height").between(0, 22000)) &
    (col("visibility").between(0, 160000)) &
    (col("air_temp").between(-932, 618)) &
    (col("dew_point").between(-982, 368)) &
    (col("sea_level_pressure").between(8600, 10900))
    )

df_no_nulls.unpersist()
final_count = df_filtered.count()
print(f"Final row count after all filtering: {final_count}")


df_filtered.coalesce(1).write.csv("gs://dsa5208-proj2/cleaned_data", header=True, mode="overwrite")
# Out:
# Sample of parsed data:
# +--------+---------+---------+--------------+----------+--------------+----------+--------+---------+------------------+
# |latitude|longitude|elevation|wind_direction|wind_speed|ceiling_height|visibility|air_temp|dew_point|sea_level_pressure|
# +--------+---------+---------+--------------+----------+--------------+----------+--------+---------+------------------+
# | 71.3213| -156.611|      4.6|          NULL|       5.0|          NULL|      NULL|  -175.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|      NULL|          NULL|      NULL|  -175.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|      NULL|          NULL|      NULL|  -175.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|      NULL|          NULL|      NULL|  -174.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|      NULL|          NULL|      NULL|  -174.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|      NULL|          NULL|      NULL|  -175.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|      NULL|          NULL|      NULL|  -174.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|      NULL|          NULL|      NULL|  -174.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|      NULL|          NULL|      NULL|  -174.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|      NULL|          NULL|      NULL|  -175.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|      NULL|          NULL|      NULL|  -175.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|      NULL|          NULL|      NULL|  -175.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|       4.0|          NULL|      NULL|  -174.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|      NULL|          NULL|      NULL|  -174.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|      NULL|          NULL|      NULL|  -174.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|      NULL|          NULL|      NULL|  -173.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|      NULL|          NULL|      NULL|  -173.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|      NULL|          NULL|      NULL|  -173.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|      NULL|          NULL|      NULL|  -173.0|     NULL|              NULL|
# | 71.3213| -156.611|      4.6|          NULL|      NULL|          NULL|      NULL|  -172.0|     NULL|              NULL|
# +--------+---------+---------+--------------+----------+--------------+----------+--------+---------+------------------+
# only showing top 20 rows
#
#
# Null counts after parsing:
# latitude: 0 nulls out of 130531842 (0.00%)
# [Stage 14:=====================================================>(830 + 2) / 832]
# longitude: 0 nulls out of 130531842 (0.00%)
# elevation: 0 nulls out of 130531842 (0.00%)
# wind_direction: 37143661 nulls out of 130531842 (28.46%)
# wind_speed: 18615382 nulls out of 130531842 (14.26%)
# ceiling_height: 68297483 nulls out of 130531842 (52.32%)
# visibility: 44706860 nulls out of 130531842 (34.25%)
# 24/11/16 14:51:15 ERROR AsyncEventQueue: Dropping event from queue dataprocEvent. This likely means one of the listeners is too slow and cannot keep up with the rate at which tasks are being started by the scheduler.
# 24/11/16 14:51:15 WARN AsyncEventQueue: Dropped 1 events from dataprocEvent since the application started.
# air_temp: 3440078 nulls out of 130531842 (2.64%)
# dew_point: 22730107 nulls out of 130531842 (17.41%)
# sea_level_pressure: 78046337 nulls out of 130531842 (59.79%)
#
# Removing rows with null values...
# Rows remaining after null removal: 18474434
#
# Applying valid range filters...
# 24/11/16 15:13:42 WARN AsyncEventQueue: Dropped 1 events from dataprocEvent since Sat Nov 16 14:51:15 UTC 2024.
# Final row count after all filtering: 18471526
# 24/11/16 15:22:27 WARN TaskSetManager: Stage 72 contains a task of very large size (1352 KiB). The maximum recommended task size is 1000 KiB.

# %% [markdown]
# ### 3.2 Prepare data by applying MinMax scaling

# %%
cleaned_df = spark.read.csv("gs://dsa5208-proj2/cleaned_data/*.csv", header=True, inferSchema=True)


feature_columns = ['latitude', 'longitude', 'elevation', 'wind_direction', 'wind_speed', 'ceiling_height', 
                   'visibility', 'air_temp', 'dew_point']

min_values = [-90000, -179999, -400, 1, 0, 0, 0, -932, -982]
max_values = [90000, 180000, 8850, 360, 900, 22000, 160000, 618, 368]


for col_name, min_val, max_val in zip(feature_columns, min_values, max_values):
    cleaned_df = cleaned_df.withColumn(col_name, (col(col_name) - min_val) / (max_val - min_val))

# %% [markdown]
# ### 3.3 Split data into train and test sets

# %%
train_data, test_data = cleaned_df.randomSplit([0.7, 0.3], seed=42)

# %% [markdown]
# ### 3.4 Assemble feature vector for model training

# %%
assembler = VectorAssembler(inputCols=feature_columns, outputCol="features")

# %% [markdown]
# ---

# %% [markdown]
# # 4. Model Training

# %% [markdown]
# ### 4.1 Cache training & test data for faster processing

# %%
train_df = train_data.cache()
test_df = test_data.cache()
# Out:
# 24/11/16 18:17:11 WARN CacheManager: Asked to cache already cached data.
# 24/11/16 18:17:11 WARN CacheManager: Asked to cache already cached data.

# %% [markdown]
# ### 4.2 Define regression models

# %%
ridge_reg = LinearRegression(featuresCol="features", labelCol="sea_level_pressure", elasticNetParam=0.0)

gbt = GBTRegressor(featuresCol="features", labelCol="sea_level_pressure")

rf = RandomForestRegressor(featuresCol="features", labelCol="sea_level_pressure")

# %% [markdown]
# ### 4.3 Define model parameter grids for hyperparameter tuning

# %%
ridge_param_grid = (ParamGridBuilder()
                        .addGrid(ridge_reg.regParam, [0.01, 0.1, 1.0])
                        .build())

gbt_param_grid = (ParamGridBuilder()
                      .addGrid(gbt.maxDepth, [5, 7, 9])
                      .addGrid(gbt.maxIter, [20, 30, 40])
                      .build())

rf_param_grid = (ParamGridBuilder()
                     .addGrid(rf.numTrees, [20, 30, 40])
                     .addGrid(rf.maxDepth, [5, 7, 9])
                     .build())

# %% [markdown]
# ### 4.4 Define RegressionEvaluator & CrossValidators for each model

# %%
# Define evaluators
evaluator = RegressionEvaluator(labelCol="sea_level_pressure", predictionCol="prediction", metricName="rmse")

# Create CrossValidator for each model
ridge_cv = CrossValidator(estimator=ridge_reg, estimatorParamMaps=ridge_param_grid, evaluator=evaluator, numFolds=3)
gbt_cv = CrossValidator(estimator=gbt, estimatorParamMaps=gbt_param_grid, evaluator=evaluator, numFolds=3)
rf_cv = CrossValidator(estimator=rf, estimatorParamMaps=rf_param_grid, evaluator=evaluator, numFolds=3)

# %% [markdown]
# ### 4.5 Create pipelines and fit each model

# %%
# Create pipelines for each model
ridge_pipeline = Pipeline(stages=[assembler, ridge_cv])
gbt_pipeline = Pipeline(stages=[assembler, gbt_cv])
rf_pipeline = Pipeline(stages=[assembler, rf_cv])

# Fit the models
ridge_model = ridge_pipeline.fit(train_df)
gbt_model = gbt_pipeline.fit(train_df)
rf_model = rf_pipeline.fit(train_df)
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.util.SizeEstimator$ (file:/usr/lib/spark/jars/spark-core_2.12-3.5.1.jar) to field java.nio.charset.Charset.name
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.util.SizeEstimator$
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 24/11/16 18:42:07 WARN DAGScheduler: Broadcasting large task binary with size 1001.8 KiB
# 24/11/16 18:42:10 WARN DAGScheduler: Broadcasting large task binary with size 1002.3 KiB
# 24/11/16 18:42:10 WARN DAGScheduler: Broadcasting large task binary with size 1002.9 KiB
# 24/11/16 18:42:11 WARN DAGScheduler: Broadcasting large task binary with size 1004.0 KiB
# 24/11/16 18:42:12 WARN DAGScheduler: Broadcasting large task binary with size 1006.3 KiB
# 24/11/16 18:42:13 WARN DAGScheduler: Broadcasting large task binary with size 1010.8 KiB
# 24/11/16 18:42:14 WARN DAGScheduler: Broadcasting large task binary with size 1019.9 KiB
# 24/11/16 18:44:10 WARN DAGScheduler: Broadcasting large task binary with size 1036.8 KiB
# 24/11/16 18:44:11 WARN DAGScheduler: Broadcasting large task binary with size 1047.7 KiB
# 24/11/16 18:44:14 WARN DAGScheduler: Broadcasting large task binary with size 1048.2 KiB
# 24/11/16 18:44:14 WARN DAGScheduler: Broadcasting large task binary with size 1048.8 KiB
# 24/11/16 18:44:15 WARN DAGScheduler: Broadcasting large task binary with size 1049.9 KiB
# 24/11/16 18:44:16 WARN DAGScheduler: Broadcasting large task binary with size 1052.2 KiB
# 24/11/16 18:44:17 WARN DAGScheduler: Broadcasting large task binary with size 1056.7 KiB
# 24/11/16 18:44:18 WARN DAGScheduler: Broadcasting large task binary with size 1065.8 KiB
# 24/11/16 18:44:19 WARN DAGScheduler: Broadcasting large task binary with size 1084.5 KiB
# 24/11/16 18:44:20 WARN DAGScheduler: Broadcasting large task binary with size 1121.4 KiB
# 24/11/16 18:44:21 WARN DAGScheduler: Broadcasting large task binary with size 1132.4 KiB
# 24/11/16 18:44:23 WARN DAGScheduler: Broadcasting large task binary with size 1132.9 KiB
# 24/11/16 18:44:24 WARN DAGScheduler: Broadcasting large task binary with size 1133.5 KiB
# 24/11/16 18:44:25 WARN DAGScheduler: Broadcasting large task binary with size 1134.6 KiB
# 24/11/16 18:44:26 WARN DAGScheduler: Broadcasting large task binary with size 1136.9 KiB
# 24/11/16 18:44:27 WARN DAGScheduler: Broadcasting large task binary with size 1141.4 KiB
# 24/11/16 18:44:28 WARN DAGScheduler: Broadcasting large task binary with size 1150.5 KiB
# 24/11/16 18:44:29 WARN DAGScheduler: Broadcasting large task binary with size 1169.2 KiB
# 24/11/16 18:44:30 WARN DAGScheduler: Broadcasting large task binary with size 1206.0 KiB
# 24/11/16 18:44:31 WARN DAGScheduler: Broadcasting large task binary with size 1216.8 KiB
# 24/11/16 18:44:34 WARN DAGScheduler: Broadcasting large task binary with size 1217.3 KiB
# 24/11/16 18:44:34 WARN DAGScheduler: Broadcasting large task binary with size 1217.8 KiB
# 24/11/16 18:44:35 WARN DAGScheduler: Broadcasting large task binary with size 1219.0 KiB
# 24/11/16 18:44:36 WARN DAGScheduler: Broadcasting large task binary with size 1221.2 KiB
# 24/11/16 18:44:37 WARN DAGScheduler: Broadcasting large task binary with size 1225.8 KiB
# 24/11/16 18:44:38 WARN DAGScheduler: Broadcasting large task binary with size 1234.9 KiB
# 24/11/16 18:44:39 WARN DAGScheduler: Broadcasting large task binary with size 1253.5 KiB
# 24/11/16 18:44:40 WARN DAGScheduler: Broadcasting large task binary with size 1290.0 KiB
# 24/11/16 18:44:41 WARN DAGScheduler: Broadcasting large task binary with size 1300.7 KiB
# 24/11/16 18:44:44 WARN DAGScheduler: Broadcasting large task binary with size 1301.2 KiB
# 24/11/16 18:44:45 WARN DAGScheduler: Broadcasting large task binary with size 1301.7 KiB
# 24/11/16 18:44:46 WARN DAGScheduler: Broadcasting large task binary with size 1302.9 KiB
# 24/11/16 18:44:47 WARN DAGScheduler: Broadcasting large task binary with size 1305.1 KiB
# 24/11/16 18:44:48 WARN DAGScheduler: Broadcasting large task binary with size 1309.7 KiB
# 24/11/16 18:44:49 WARN DAGScheduler: Broadcasting large task binary with size 1318.7 KiB
# 24/11/16 18:44:50 WARN DAGScheduler: Broadcasting large task binary with size 1337.4 KiB
# 24/11/16 18:44:51 WARN DAGScheduler: Broadcasting large task binary with size 1374.3 KiB
# 24/11/16 18:44:52 WARN DAGScheduler: Broadcasting large task binary with size 1385.3 KiB
# 24/11/16 18:44:54 WARN DAGScheduler: Broadcasting large task binary with size 1385.8 KiB
# 24/11/16 18:44:55 WARN DAGScheduler: Broadcasting large task binary with size 1386.4 KiB
# 24/11/16 18:44:56 WARN DAGScheduler: Broadcasting large task binary with size 1387.5 KiB
# 24/11/16 18:44:57 WARN DAGScheduler: Broadcasting large task binary with size 1389.8 KiB
# 24/11/16 18:44:58 WARN DAGScheduler: Broadcasting large task binary with size 1394.3 KiB
# 24/11/16 18:44:59 WARN DAGScheduler: Broadcasting large task binary with size 1403.4 KiB
# 24/11/16 18:45:00 WARN DAGScheduler: Broadcasting large task binary with size 1422.1 KiB
# 24/11/16 18:45:01 WARN DAGScheduler: Broadcasting large task binary with size 1458.9 KiB
# 24/11/16 18:45:02 WARN DAGScheduler: Broadcasting large task binary with size 1469.7 KiB
# 24/11/16 18:45:05 WARN DAGScheduler: Broadcasting large task binary with size 1470.1 KiB
# 24/11/16 18:45:06 WARN DAGScheduler: Broadcasting large task binary with size 1470.7 KiB
# 24/11/16 18:45:07 WARN DAGScheduler: Broadcasting large task binary with size 1471.8 KiB
# 24/11/16 18:45:08 WARN DAGScheduler: Broadcasting large task binary with size 1474.1 KiB
# 24/11/16 18:45:08 WARN DAGScheduler: Broadcasting large task binary with size 1478.6 KiB
# 24/11/16 18:45:09 WARN DAGScheduler: Broadcasting large task binary with size 1487.7 KiB
# 24/11/16 18:45:10 WARN DAGScheduler: Broadcasting large task binary with size 1506.4 KiB
# 24/11/16 18:45:11 WARN DAGScheduler: Broadcasting large task binary with size 1543.2 KiB
# 24/11/16 18:45:12 WARN DAGScheduler: Broadcasting large task binary with size 1553.6 KiB
# 24/11/16 18:45:15 WARN DAGScheduler: Broadcasting large task binary with size 1554.1 KiB
# 24/11/16 18:45:16 WARN DAGScheduler: Broadcasting large task binary with size 1554.7 KiB
# 24/11/16 18:45:17 WARN DAGScheduler: Broadcasting large task binary with size 1555.8 KiB
# 24/11/16 18:45:18 WARN DAGScheduler: Broadcasting large task binary with size 1558.1 KiB
# 24/11/16 18:45:19 WARN DAGScheduler: Broadcasting large task binary with size 1562.6 KiB
# 24/11/16 18:45:20 WARN DAGScheduler: Broadcasting large task binary with size 1571.7 KiB
# 24/11/16 18:45:20 WARN DAGScheduler: Broadcasting large task binary with size 1590.4 KiB
# 24/11/16 18:45:22 WARN DAGScheduler: Broadcasting large task binary with size 1627.2 KiB
# 24/11/16 18:45:23 WARN DAGScheduler: Broadcasting large task binary with size 1638.3 KiB
# 24/11/16 18:45:25 WARN DAGScheduler: Broadcasting large task binary with size 1638.7 KiB
# 24/11/16 18:45:27 WARN DAGScheduler: Broadcasting large task binary with size 1639.3 KiB
# 24/11/16 18:45:27 WARN DAGScheduler: Broadcasting large task binary with size 1640.4 KiB
# 24/11/16 18:45:28 WARN DAGScheduler: Broadcasting large task binary with size 1642.7 KiB
# 24/11/16 18:45:29 WARN DAGScheduler: Broadcasting large task binary with size 1647.2 KiB
# 24/11/16 18:45:30 WARN DAGScheduler: Broadcasting large task binary with size 1656.3 KiB
# 24/11/16 18:45:31 WARN DAGScheduler: Broadcasting large task binary with size 1675.1 KiB
# 24/11/16 18:45:32 WARN DAGScheduler: Broadcasting large task binary with size 1711.9 KiB
# 24/11/16 18:45:33 WARN DAGScheduler: Broadcasting large task binary with size 1723.0 KiB
# 24/11/16 18:45:36 WARN DAGScheduler: Broadcasting large task binary with size 1723.5 KiB
# 24/11/16 18:45:37 WARN DAGScheduler: Broadcasting large task binary with size 1724.0 KiB
# 24/11/16 18:45:37 WARN DAGScheduler: Broadcasting large task binary with size 1725.2 KiB
# 24/11/16 18:45:38 WARN DAGScheduler: Broadcasting large task binary with size 1727.4 KiB
# 24/11/16 18:45:40 WARN DAGScheduler: Broadcasting large task binary with size 1732.0 KiB
# 24/11/16 18:45:41 WARN DAGScheduler: Broadcasting large task binary with size 1741.1 KiB
# 24/11/16 18:45:42 WARN DAGScheduler: Broadcasting large task binary with size 1759.8 KiB
# 24/11/16 18:45:43 WARN DAGScheduler: Broadcasting large task binary with size 1796.5 KiB
# 24/11/16 18:47:37 WARN DAGScheduler: Broadcasting large task binary with size 1036.8 KiB
# 24/11/16 18:47:38 WARN DAGScheduler: Broadcasting large task binary with size 1047.7 KiB
# 24/11/16 18:47:41 WARN DAGScheduler: Broadcasting large task binary with size 1048.2 KiB
# 24/11/16 18:47:42 WARN DAGScheduler: Broadcasting large task binary with size 1048.8 KiB
# 24/11/16 18:47:42 WARN DAGScheduler: Broadcasting large task binary with size 1049.9 KiB
# 24/11/16 18:47:43 WARN DAGScheduler: Broadcasting large task binary with size 1052.2 KiB
# 24/11/16 18:47:44 WARN DAGScheduler: Broadcasting large task binary with size 1056.7 KiB
# 24/11/16 18:47:45 WARN DAGScheduler: Broadcasting large task binary with size 1065.8 KiB
# 24/11/16 18:47:46 WARN DAGScheduler: Broadcasting large task binary with size 1084.5 KiB
# 24/11/16 18:47:47 WARN DAGScheduler: Broadcasting large task binary with size 1121.4 KiB
# 24/11/16 18:47:48 WARN DAGScheduler: Broadcasting large task binary with size 1132.4 KiB
# 24/11/16 18:47:51 WARN DAGScheduler: Broadcasting large task binary with size 1132.9 KiB
# 24/11/16 18:47:52 WARN DAGScheduler: Broadcasting large task binary with size 1133.5 KiB
# 24/11/16 18:47:52 WARN DAGScheduler: Broadcasting large task binary with size 1134.6 KiB
# 24/11/16 18:47:53 WARN DAGScheduler: Broadcasting large task binary with size 1136.9 KiB
# 24/11/16 18:47:54 WARN DAGScheduler: Broadcasting large task binary with size 1141.4 KiB
# 24/11/16 18:47:55 WARN DAGScheduler: Broadcasting large task binary with size 1150.5 KiB
# 24/11/16 18:47:56 WARN DAGScheduler: Broadcasting large task binary with size 1169.2 KiB
# 24/11/16 18:47:57 WARN DAGScheduler: Broadcasting large task binary with size 1206.0 KiB
# 24/11/16 18:47:58 WARN DAGScheduler: Broadcasting large task binary with size 1216.8 KiB
# 24/11/16 18:48:01 WARN DAGScheduler: Broadcasting large task binary with size 1217.3 KiB
# 24/11/16 18:48:02 WARN DAGScheduler: Broadcasting large task binary with size 1217.8 KiB
# 24/11/16 18:48:03 WARN DAGScheduler: Broadcasting large task binary with size 1219.0 KiB
# 24/11/16 18:48:04 WARN DAGScheduler: Broadcasting large task binary with size 1221.2 KiB
# 24/11/16 18:48:04 WARN DAGScheduler: Broadcasting large task binary with size 1225.8 KiB
# 24/11/16 18:48:05 WARN DAGScheduler: Broadcasting large task binary with size 1234.9 KiB
# 24/11/16 18:48:06 WARN DAGScheduler: Broadcasting large task binary with size 1253.5 KiB
# 24/11/16 18:48:07 WARN DAGScheduler: Broadcasting large task binary with size 1290.0 KiB
# 24/11/16 18:48:08 WARN DAGScheduler: Broadcasting large task binary with size 1300.7 KiB
# 24/11/16 18:48:11 WARN DAGScheduler: Broadcasting large task binary with size 1301.2 KiB
# 24/11/16 18:48:12 WARN DAGScheduler: Broadcasting large task binary with size 1301.7 KiB
# 24/11/16 18:48:13 WARN DAGScheduler: Broadcasting large task binary with size 1302.9 KiB
# 24/11/16 18:48:13 WARN DAGScheduler: Broadcasting large task binary with size 1305.1 KiB
# 24/11/16 18:48:14 WARN DAGScheduler: Broadcasting large task binary with size 1309.7 KiB
# 24/11/16 18:48:15 WARN DAGScheduler: Broadcasting large task binary with size 1318.7 KiB
# 24/11/16 18:48:16 WARN DAGScheduler: Broadcasting large task binary with size 1337.4 KiB
# 24/11/16 18:48:17 WARN DAGScheduler: Broadcasting large task binary with size 1374.3 KiB
# 24/11/16 18:48:18 WARN DAGScheduler: Broadcasting large task binary with size 1385.3 KiB
# 24/11/16 18:48:21 WARN DAGScheduler: Broadcasting large task binary with size 1385.8 KiB
# 24/11/16 18:48:22 WARN DAGScheduler: Broadcasting large task binary with size 1386.4 KiB
# 24/11/16 18:48:23 WARN DAGScheduler: Broadcasting large task binary with size 1387.5 KiB
# 24/11/16 18:48:23 WARN DAGScheduler: Broadcasting large task binary with size 1389.8 KiB
# 24/11/16 18:48:24 WARN DAGScheduler: Broadcasting large task binary with size 1394.3 KiB
# 24/11/16 18:48:25 WARN DAGScheduler: Broadcasting large task binary with size 1403.4 KiB
# 24/11/16 18:48:26 WARN DAGScheduler: Broadcasting large task binary with size 1422.1 KiB
# 24/11/16 18:48:27 WARN DAGScheduler: Broadcasting large task binary with size 1458.9 KiB
# 24/11/16 18:48:28 WARN DAGScheduler: Broadcasting large task binary with size 1469.7 KiB
# 24/11/16 18:48:31 WARN DAGScheduler: Broadcasting large task binary with size 1470.1 KiB
# 24/11/16 18:48:31 WARN DAGScheduler: Broadcasting large task binary with size 1470.7 KiB
# 24/11/16 18:48:32 WARN DAGScheduler: Broadcasting large task binary with size 1471.8 KiB
# 24/11/16 18:48:33 WARN DAGScheduler: Broadcasting large task binary with size 1474.1 KiB
# 24/11/16 18:48:34 WARN DAGScheduler: Broadcasting large task binary with size 1478.6 KiB
# 24/11/16 18:48:35 WARN DAGScheduler: Broadcasting large task binary with size 1487.7 KiB
# 24/11/16 18:48:35 WARN DAGScheduler: Broadcasting large task binary with size 1506.4 KiB
# 24/11/16 18:48:37 WARN DAGScheduler: Broadcasting large task binary with size 1543.2 KiB
# 24/11/16 18:48:38 WARN DAGScheduler: Broadcasting large task binary with size 1553.6 KiB
# 24/11/16 18:48:40 WARN DAGScheduler: Broadcasting large task binary with size 1554.1 KiB
# 24/11/16 18:48:41 WARN DAGScheduler: Broadcasting large task binary with size 1554.7 KiB
# 24/11/16 18:48:42 WARN DAGScheduler: Broadcasting large task binary with size 1555.8 KiB
# 24/11/16 18:48:43 WARN DAGScheduler: Broadcasting large task binary with size 1558.1 KiB
# 24/11/16 18:48:44 WARN DAGScheduler: Broadcasting large task binary with size 1562.6 KiB
# 24/11/16 18:48:45 WARN DAGScheduler: Broadcasting large task binary with size 1571.7 KiB
# 24/11/16 18:48:46 WARN DAGScheduler: Broadcasting large task binary with size 1590.4 KiB
# 24/11/16 18:48:47 WARN DAGScheduler: Broadcasting large task binary with size 1627.2 KiB
# 24/11/16 18:48:48 WARN DAGScheduler: Broadcasting large task binary with size 1638.3 KiB
# 24/11/16 18:48:50 WARN DAGScheduler: Broadcasting large task binary with size 1638.7 KiB
# 24/11/16 18:48:51 WARN DAGScheduler: Broadcasting large task binary with size 1639.3 KiB
# 24/11/16 18:48:52 WARN DAGScheduler: Broadcasting large task binary with size 1640.4 KiB
# 24/11/16 18:48:53 WARN DAGScheduler: Broadcasting large task binary with size 1642.7 KiB
# 24/11/16 18:48:53 WARN DAGScheduler: Broadcasting large task binary with size 1647.2 KiB
# 24/11/16 18:48:54 WARN DAGScheduler: Broadcasting large task binary with size 1656.3 KiB
# 24/11/16 18:48:55 WARN DAGScheduler: Broadcasting large task binary with size 1675.1 KiB
# 24/11/16 18:48:56 WARN DAGScheduler: Broadcasting large task binary with size 1711.9 KiB
# 24/11/16 18:48:57 WARN DAGScheduler: Broadcasting large task binary with size 1723.0 KiB
# 24/11/16 18:48:59 WARN DAGScheduler: Broadcasting large task binary with size 1723.5 KiB
# 24/11/16 18:49:00 WARN DAGScheduler: Broadcasting large task binary with size 1724.0 KiB
# 24/11/16 18:49:01 WARN DAGScheduler: Broadcasting large task binary with size 1725.2 KiB
# 24/11/16 18:49:02 WARN DAGScheduler: Broadcasting large task binary with size 1727.4 KiB
# 24/11/16 18:49:03 WARN DAGScheduler: Broadcasting large task binary with size 1732.0 KiB
# 24/11/16 18:49:04 WARN DAGScheduler: Broadcasting large task binary with size 1741.1 KiB
# 24/11/16 18:49:05 WARN DAGScheduler: Broadcasting large task binary with size 1759.8 KiB
# 24/11/16 18:49:05 WARN DAGScheduler: Broadcasting large task binary with size 1796.5 KiB
# 24/11/16 18:49:07 WARN DAGScheduler: Broadcasting large task binary with size 1807.2 KiB
# 24/11/16 18:49:09 WARN DAGScheduler: Broadcasting large task binary with size 1807.7 KiB
# 24/11/16 18:49:10 WARN DAGScheduler: Broadcasting large task binary with size 1808.3 KiB
# 24/11/16 18:49:11 WARN DAGScheduler: Broadcasting large task binary with size 1809.4 KiB
# 24/11/16 18:49:12 WARN DAGScheduler: Broadcasting large task binary with size 1811.7 KiB
# 24/11/16 18:49:13 WARN DAGScheduler: Broadcasting large task binary with size 1816.2 KiB
# 24/11/16 18:49:14 WARN DAGScheduler: Broadcasting large task binary with size 1825.3 KiB
# 24/11/16 18:49:15 WARN DAGScheduler: Broadcasting large task binary with size 1844.0 KiB
# 24/11/16 18:49:16 WARN DAGScheduler: Broadcasting large task binary with size 1880.8 KiB
# 24/11/16 18:49:17 WARN DAGScheduler: Broadcasting large task binary with size 1891.6 KiB
# 24/11/16 18:49:19 WARN DAGScheduler: Broadcasting large task binary with size 1892.1 KiB
# 24/11/16 18:49:20 WARN DAGScheduler: Broadcasting large task binary with size 1892.7 KiB
# 24/11/16 18:49:21 WARN DAGScheduler: Broadcasting large task binary with size 1893.8 KiB
# 24/11/16 18:52:54 WARN DAGScheduler: Broadcasting large task binary with size 1132.9 KiB
# 24/11/16 18:52:55 WARN DAGScheduler: Broadcasting large task binary with size 1133.5 KiB
# 24/11/16 18:52:56 WARN DAGScheduler: Broadcasting large task binary with size 1134.6 KiB
# 24/11/16 18:52:57 WARN DAGScheduler: Broadcasting large task binary with size 1136.9 KiB
# 24/11/16 18:52:57 WARN DAGScheduler: Broadcasting large task binary with size 1141.4 KiB
# 24/11/16 18:52:58 WARN DAGScheduler: Broadcasting large task binary with size 1150.5 KiB
# 24/11/16 18:52:59 WARN DAGScheduler: Broadcasting large task binary with size 1169.2 KiB
# 24/11/16 18:53:00 WARN DAGScheduler: Broadcasting large task binary with size 1206.0 KiB
# 24/11/16 18:53:01 WARN DAGScheduler: Broadcasting large task binary with size 1216.8 KiB
# 24/11/16 18:53:04 WARN DAGScheduler: Broadcasting large task binary with size 1217.3 KiB
# 24/11/16 18:53:05 WARN DAGScheduler: Broadcasting large task binary with size 1217.8 KiB
# 24/11/16 18:53:06 WARN DAGScheduler: Broadcasting large task binary with size 1219.0 KiB
# 24/11/16 18:53:07 WARN DAGScheduler: Broadcasting large task binary with size 1221.2 KiB
# 24/11/16 18:53:07 WARN DAGScheduler: Broadcasting large task binary with size 1225.8 KiB
# 24/11/16 18:53:08 WARN DAGScheduler: Broadcasting large task binary with size 1234.9 KiB
# 24/11/16 18:53:09 WARN DAGScheduler: Broadcasting large task binary with size 1253.5 KiB
# 24/11/16 18:53:10 WARN DAGScheduler: Broadcasting large task binary with size 1290.0 KiB
# 24/11/16 18:53:11 WARN DAGScheduler: Broadcasting large task binary with size 1300.7 KiB
# 24/11/16 18:53:14 WARN DAGScheduler: Broadcasting large task binary with size 1301.2 KiB
# 24/11/16 18:53:15 WARN DAGScheduler: Broadcasting large task binary with size 1301.7 KiB
# 24/11/16 18:53:16 WARN DAGScheduler: Broadcasting large task binary with size 1302.9 KiB
# 24/11/16 18:53:16 WARN DAGScheduler: Broadcasting large task binary with size 1305.1 KiB
# 24/11/16 18:53:17 WARN DAGScheduler: Broadcasting large task binary with size 1309.7 KiB
# 24/11/16 18:53:18 WARN DAGScheduler: Broadcasting large task binary with size 1318.7 KiB
# 24/11/16 18:53:19 WARN DAGScheduler: Broadcasting large task binary with size 1337.4 KiB
# 24/11/16 18:53:20 WARN DAGScheduler: Broadcasting large task binary with size 1374.3 KiB
# 24/11/16 18:53:21 WARN DAGScheduler: Broadcasting large task binary with size 1385.3 KiB
# 24/11/16 18:53:23 WARN DAGScheduler: Broadcasting large task binary with size 1385.8 KiB
# 24/11/16 18:53:24 WARN DAGScheduler: Broadcasting large task binary with size 1386.4 KiB
# 24/11/16 18:53:25 WARN DAGScheduler: Broadcasting large task binary with size 1387.5 KiB
# 24/11/16 18:53:26 WARN DAGScheduler: Broadcasting large task binary with size 1389.8 KiB
# 24/11/16 18:53:27 WARN DAGScheduler: Broadcasting large task binary with size 1394.3 KiB
# 24/11/16 18:53:28 WARN DAGScheduler: Broadcasting large task binary with size 1403.4 KiB
# 24/11/16 18:53:29 WARN DAGScheduler: Broadcasting large task binary with size 1422.1 KiB
# 24/11/16 18:53:29 WARN DAGScheduler: Broadcasting large task binary with size 1458.9 KiB
# 24/11/16 18:53:30 WARN DAGScheduler: Broadcasting large task binary with size 1469.7 KiB
# 24/11/16 18:53:33 WARN DAGScheduler: Broadcasting large task binary with size 1470.1 KiB
# 24/11/16 18:53:34 WARN DAGScheduler: Broadcasting large task binary with size 1470.7 KiB
# 24/11/16 18:53:35 WARN DAGScheduler: Broadcasting large task binary with size 1471.8 KiB
# 24/11/16 18:53:36 WARN DAGScheduler: Broadcasting large task binary with size 1474.1 KiB
# 24/11/16 18:53:36 WARN DAGScheduler: Broadcasting large task binary with size 1478.6 KiB
# 24/11/16 18:53:37 WARN DAGScheduler: Broadcasting large task binary with size 1487.7 KiB
# 24/11/16 18:53:38 WARN DAGScheduler: Broadcasting large task binary with size 1506.4 KiB
# 24/11/16 18:53:39 WARN DAGScheduler: Broadcasting large task binary with size 1543.2 KiB
# 24/11/16 18:53:40 WARN DAGScheduler: Broadcasting large task binary with size 1553.6 KiB
# 24/11/16 18:53:43 WARN DAGScheduler: Broadcasting large task binary with size 1554.1 KiB
# 24/11/16 18:53:44 WARN DAGScheduler: Broadcasting large task binary with size 1554.7 KiB
# 24/11/16 18:53:45 WARN DAGScheduler: Broadcasting large task binary with size 1555.8 KiB
# 24/11/16 18:53:46 WARN DAGScheduler: Broadcasting large task binary with size 1558.1 KiB
# 24/11/16 18:53:46 WARN DAGScheduler: Broadcasting large task binary with size 1562.6 KiB
# 24/11/16 18:53:47 WARN DAGScheduler: Broadcasting large task binary with size 1571.7 KiB
# 24/11/16 18:53:48 WARN DAGScheduler: Broadcasting large task binary with size 1590.4 KiB
# 24/11/16 18:53:49 WARN DAGScheduler: Broadcasting large task binary with size 1627.2 KiB
# 24/11/16 18:53:50 WARN DAGScheduler: Broadcasting large task binary with size 1638.3 KiB
# 24/11/16 18:53:53 WARN DAGScheduler: Broadcasting large task binary with size 1638.7 KiB
# 24/11/16 18:53:54 WARN DAGScheduler: Broadcasting large task binary with size 1639.3 KiB
# 24/11/16 18:53:54 WARN DAGScheduler: Broadcasting large task binary with size 1640.4 KiB
# 24/11/16 18:53:55 WARN DAGScheduler: Broadcasting large task binary with size 1642.7 KiB
# 24/11/16 18:53:56 WARN DAGScheduler: Broadcasting large task binary with size 1647.2 KiB
# 24/11/16 18:53:57 WARN DAGScheduler: Broadcasting large task binary with size 1656.3 KiB
# 24/11/16 18:53:58 WARN DAGScheduler: Broadcasting large task binary with size 1675.1 KiB
# 24/11/16 18:53:59 WARN DAGScheduler: Broadcasting large task binary with size 1711.9 KiB
# 24/11/16 18:54:00 WARN DAGScheduler: Broadcasting large task binary with size 1723.0 KiB
# 24/11/16 18:54:03 WARN DAGScheduler: Broadcasting large task binary with size 1723.5 KiB
# 24/11/16 18:54:04 WARN DAGScheduler: Broadcasting large task binary with size 1724.0 KiB
# 24/11/16 18:54:05 WARN DAGScheduler: Broadcasting large task binary with size 1725.2 KiB
# 24/11/16 18:54:05 WARN DAGScheduler: Broadcasting large task binary with size 1727.4 KiB
# 24/11/16 18:54:06 WARN DAGScheduler: Broadcasting large task binary with size 1732.0 KiB
# 24/11/16 18:54:07 WARN DAGScheduler: Broadcasting large task binary with size 1741.1 KiB
# 24/11/16 18:54:08 WARN DAGScheduler: Broadcasting large task binary with size 1759.8 KiB
# 24/11/16 18:54:09 WARN DAGScheduler: Broadcasting large task binary with size 1796.5 KiB
# 24/11/16 18:54:10 WARN DAGScheduler: Broadcasting large task binary with size 1807.2 KiB
# 24/11/16 18:54:12 WARN DAGScheduler: Broadcasting large task binary with size 1807.7 KiB
# 24/11/16 18:54:13 WARN DAGScheduler: Broadcasting large task binary with size 1808.3 KiB
# 24/11/16 18:54:14 WARN DAGScheduler: Broadcasting large task binary with size 1809.4 KiB
# 24/11/16 18:54:15 WARN DAGScheduler: Broadcasting large task binary with size 1811.7 KiB
# 24/11/16 18:54:16 WARN DAGScheduler: Broadcasting large task binary with size 1816.2 KiB
# 24/11/16 18:54:17 WARN DAGScheduler: Broadcasting large task binary with size 1825.3 KiB
# 24/11/16 18:54:18 WARN DAGScheduler: Broadcasting large task binary with size 1844.0 KiB
# 24/11/16 18:54:19 WARN DAGScheduler: Broadcasting large task binary with size 1880.8 KiB
# 24/11/16 18:54:20 WARN DAGScheduler: Broadcasting large task binary with size 1891.6 KiB
# 24/11/16 18:54:22 WARN DAGScheduler: Broadcasting large task binary with size 1892.1 KiB
# 24/11/16 18:54:23 WARN DAGScheduler: Broadcasting large task binary with size 1892.7 KiB
# 24/11/16 18:54:24 WARN DAGScheduler: Broadcasting large task binary with size 1893.8 KiB
# 24/11/16 18:54:25 WARN DAGScheduler: Broadcasting large task binary with size 1896.1 KiB
# 24/11/16 18:54:26 WARN DAGScheduler: Broadcasting large task binary with size 1900.6 KiB
# 24/11/16 18:54:27 WARN DAGScheduler: Broadcasting large task binary with size 1909.7 KiB
# 24/11/16 18:54:28 WARN DAGScheduler: Broadcasting large task binary with size 1928.4 KiB
# 24/11/16 18:54:29 WARN DAGScheduler: Broadcasting large task binary with size 1965.2 KiB
# 24/11/16 18:54:30 WARN DAGScheduler: Broadcasting large task binary with size 1976.3 KiB
# 24/11/16 18:54:32 WARN DAGScheduler: Broadcasting large task binary with size 1976.7 KiB
# 24/11/16 18:54:33 WARN DAGScheduler: Broadcasting large task binary with size 1977.3 KiB
# 24/11/16 18:54:34 WARN DAGScheduler: Broadcasting large task binary with size 1978.4 KiB
# 24/11/16 18:54:35 WARN DAGScheduler: Broadcasting large task binary with size 1980.7 KiB
# 24/11/16 18:54:36 WARN DAGScheduler: Broadcasting large task binary with size 1985.2 KiB
# 24/11/16 18:54:37 WARN DAGScheduler: Broadcasting large task binary with size 1994.3 KiB
# 24/11/16 18:54:37 WARN DAGScheduler: Broadcasting large task binary with size 2013.0 KiB
# 24/11/16 18:54:38 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 24/11/16 18
WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB

# %% [markdown]
# ### 4.6 Make predictions on the train and test sets

# %%
ridge_train_predictions = ridge_model.transform(train_df)
gbt_train_predictions = gbt_model.transform(train_df)
rf_train_predictions = rf_model.transform(train_df)

ridge_test_predictions = ridge_model.transform(test_df)
gbt_test_predictions = gbt_model.transform(test_df)
rf_test_predictions = rf_model.transform(test_df)

# %% [markdown]
# # 5. Model Evaluation & Optimization

# %% [markdown]
# ### 5.1 Calculate RMSE of model predictions on train and test sets

# %%
ridge_train_rmse = evaluator.evaluate(ridge_train_predictions)
gbt_train_rmse = evaluator.evaluate(gbt_train_predictions)
rf_train_rmse = evaluator.evaluate(rf_train_predictions)

ridge_test_rmse = evaluator.evaluate(ridge_test_predictions)
gbt_test_rmse = evaluator.evaluate(gbt_test_predictions)
rf_test_rmse = evaluator.evaluate(rf_test_predictions)

# %%
print(f"\nRidge Regression Train RMSE: {ridge_train_rmse}")
print(f"Gradient-Boosted Tree Train RMSE: {gbt_train_rmse}")
print(f"Random Forest Train RMSE: {rf_train_rmse}\n")

print(f"\nRidge Regression Test RMSE: {ridge_test_rmse}")
print(f"Gradient-Boosted Tree Test RMSE: {gbt_test_rmse}")
print(f"Random Forest Test RMSE: {rf_test_rmse}\n")
# Out:
# Ridge Regression Train RMSE: 86.09802416032562
# Gradient-Boosted Tree Train RMSE: 72.59316352077796
# Random Forest Train RMSE: 78.11254781302699
#
#
# Ridge Regression Test RMSE: 86.09335444183954
# Gradient-Boosted Tree Test RMSE: 72.69570278675752
# Random Forest Test RMSE: 78.09106589460644

# %% [markdown]
# ### 5.2 Identify the optimized hyperparameters for each model

# %%
ridge_best_model = ridge_model.stages[-1].bestModel
gbt_best_model = gbt_model.stages[-1].bestModel
rf_best_model = rf_model.stages[-1].bestModel

print("\nBest Hyperparameters:")

print(f"Ridge Regression: regParam = {ridge_best_model._java_obj.parent().getRegParam()}")

print(f"GBT: maxDepth = {gbt_best_model._java_obj.parent().getMaxDepth()},\
    maxIter = {gbt_best_model._java_obj.parent().getMaxIter()}")

print(f"Random Forest: numTrees = {rf_best_model._java_obj.parent().getNumTrees()},\
      maxDepth = {rf_best_model._java_obj.parent().getMaxDepth()}")
# Out:
# Best Hyperparameters:
# Ridge Regression: regParam = 0.01
# GBT: maxDepth = 9,    maxIter = 40
# Random Forest: numTrees = 40,      maxDepth = 9

# %%
train_df.unpersist()
test_df.unpersist()
# Out:
# DataFrame[latitude: double, longitude: double, elevation: double, wind_direction: double, wind_speed: double, ceiling_height: double, visibility: double, air_temp: double, dew_point: double, sea_level_pressure: double]

# %%
# Save each trained model to GCS
ridge_model.save("gs://dsa5208-proj2/saved_models/ridge_model")
gbt_model.save("gs://dsa5208-proj2/saved_models/gbt_model")
rf_model.save("gs://dsa5208-proj2/saved_models/rf_model")
# Out:
# 24/11/16 21:35:41 WARN TaskSetManager: Stage 12973 contains a task of very large size (1697 KiB). The maximum recommended task size is 1000 KiB.
# 24/11/16 21:35:56 WARN TaskSetManager: Stage 12985 contains a task of very large size (1642 KiB). The maximum recommended task size is 1000 KiB.
